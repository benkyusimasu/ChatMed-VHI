# %%
from huggingface_hub import login
login()
# Out:
# <center><img src="https://huggingface.co/front/assets/huggingface_logo-noborder.svg" width="100" alt="Hugging Face"><br><br><p>To log in, open this URL and enter the code:</p><p><a href="https://hf.co/oauth/device" target="_blank"><b>https://hf.co/oauth/device</b></a></p><p style="font-size: 1.6em; letter-spacing: 0.3em; font-family: monospace;"><b>71YU-PHNL</b></p></center>
# <center><i>Waiting for authorization...</i></center>
# <center><b style='color: red;'>Login failed: Device code expired (timeout). Please try again.</b></center>

# %%
# !pip install -U datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 555.1/555.1 kB 40.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 21.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
# !pip install --upgrade transformers peft tokenizers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 102.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.12.1
#     Uninstalling transformers-5.12.1:
#       Successfully uninstalled transformers-5.12.1
# ...

# %%
# !rm -rf /content/local_results/*

# %%
# !python3 "/content/drive/MyDrive/Colab Notebooks/BIOtoken.py" \
--model_name_or_path "michiyasunaga/BioLinkBERT-base" \
--train_file "/content/drive/MyDrive/数据/Training size/50%_data_train/50%_Data_train.json" \
--validation_file "/content/drive/MyDrive/数据/Val/Data_val.json" \
--test_file "/content/drive/MyDrive/数据/Test/Data_test.json" \
--do_train --do_eval --do_predict \
--preprocessing_num_workers 10 \
--per_device_train_batch_size 16 \
--gradient_accumulation_steps 4 \
--learning_rate 3e-5 \
--num_train_epochs 15 \
--max_seq_length 384 \
--doc_stride 128 \
--save_strategy epoch \
--eval_strategy epoch \
--load_best_model_at_end \
--metric_for_best_model eval_bio_strict_precision \
--greater_is_better true \
--save_total_limit 1 \
--output_dir "/content/drive/MyDrive/数据/50%_data_train_BiolinkBert_results" \
--report_to none \
--logging_strategy "steps" \
--logging_steps 20
# Out:
# Generating train split: 4002 examples [00:01, 3808.33 examples/s]
# Generating validation split: 669 examples [00:00, 99882.15 examples/s]
# Generating test split: 559 examples [00:00, 97041.34 examples/s]
# config.json: 100% 559/559 [00:00<00:00, 2.93MB/s]
# ...
# 07/11/2026 03:38:57 - WARNING - huggingface_hub.utils._http - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json: 100% 379/379 [00:00<00:00, 2.52MB/s]
# vocab.txt: 100% 225k/225k [00:00<00:00, 52.4MB/s]
# tokenizer.json: 100% 447k/447k [00:00<00:00, 112MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 701kB/s]
# pytorch_model.bin: 100% 433M/433M [00:06<00:00, 63.8MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 21235.62it/s]
# [WARNING|loading_report.py:269] 2026-07-11 03:39:08,387 >> BertForQuestionAnswering LOAD REPORT from: michiyasunaga/BioLinkBERT-base
# Key                      | Status     |
# ...

# %%
# 创建一个专门存放 BioLinkBERT 最佳结果的网盘文件夹
# !mkdir -p "/content/drive/MyDrive/数据/BioLinkBert_final_best"

# 将本地成果全部复制过去
# !cp -r /content/local_results/* "/content/drive/MyDrive/数据/BioLinkBert_final_best/"

# %%
# !python3 "/content/drive/MyDrive/Colab Notebooks/BIOtoken.py" \
--model_name_or_path "michiyasunaga/BioLinkBERT-base" \
--train_file "/content/drive/MyDrive/数据/Training size/50%_data_train/50%_Data_train.json" \
--validation_file "/content/drive/MyDrive/数据/Val/Data_val.json" \
--test_file "/content/drive/MyDrive/数据/Test/Data_test.json" \
--do_train --do_eval --do_predict \
--preprocessing_num_workers 10 \
--per_device_train_batch_size 16 \
--gradient_accumulation_steps 4 \
--learning_rate 3e-5 \
--num_train_epochs 15 \
--max_seq_length 384 \
--doc_stride 128 \
--save_strategy epoch \
--eval_strategy epoch \
--load_best_model_at_end \
--metric_for_best_model eval_bio_strict_precision \
--greater_is_better true \
--save_total_limit 1 \
--output_dir "/content/drive/MyDrive/数据/50%_data_train_BiolinkBert_results" \
--report_to none \
--logging_strategy "steps" \
--logging_steps 20 \
--overwrite_cache true \
--resume_from_checkpoint "/content/drive/MyDrive/数据/50%_data_train_BiolinkBert_results/checkpoint-384"
# Out:
# Generating train split: 2003 examples [00:00, 85415.28 examples/s]
# Generating validation split: 669 examples [00:00, 77556.37 examples/s]
# Generating test split: 559 examples [00:00, 90448.88 examples/s]
# ...
# 07/11/2026 02:13:37 - WARNING - huggingface_hub.utils._http - Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 559/559 [00:00<00:00, 2.08MB/s]
# tokenizer_config.json: 100% 379/379 [00:00<00:00, 1.82MB/s]
# vocab.txt: 100% 225k/225k [00:00<00:00, 20.6MB/s]
# tokenizer.json: 100% 447k/447k [00:00<00:00, 58.7MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 649kB/s]
# pytorch_model.bin: 100% 433M/433M [00:03<00:00, 143MB/s]
# Loading weights: 100% 197/197 [00:00<00:00, 20289.70it/s]
# [WARNING|loading_report.py:269] 2026-07-11 02:13:42,915 >> BertForQuestionAnswering LOAD REPORT from: michiyasunaga/BioLinkBERT-base
# Key                      | Status     |
# ...

# %%
# !python3 "/content/drive/MyDrive/Colab Notebooks/BIOtoken.py" \
--model_name_or_path "/content/drive/MyDrive/数据/PubmedBert_final_best" \
--train_file "/content/drive/MyDrive/数据/Train/Data_train.json" \
--validation_file "/content/drive/MyDrive/数据/Val/Data_val.json" \
--test_file "/content/drive/MyDrive/数据/Test/Data_test.json" \
--do_eval --do_predict \
--max_seq_length 384 \
--doc_stride 128 \
--output_dir "/content/drive/MyDrive/数据/PubmedBert_final_best" \
--overwrite_cache true
# Out:
# Generating train split: 4006 examples [00:00, 138259.35 examples/s]
# Generating validation split: 674 examples [00:00, 94807.19 examples/s]
# Generating test split: 559 examples [00:00, 103588.23 examples/s]
# Loading weights: 100% 199/199 [00:10<00:00, 18.19it/s]
# Running tokenizer on validation dataset: 100% 674/674 [00:01<00:00, 668.71 examples/s]
# Running tokenizer on prediction dataset: 100% 559/559 [00:00<00:00, 1722.70 examples/s]
#  99% 84/85 [00:13<00:00,  5.99it/s]
#   0% 0/674 [00:00<?, ?it/s]
#   6% 39/674 [00:00<00:01, 380.97it/s]
#  12% 78/674 [00:00<00:01, 379.32it/s]
#  17% 116/674 [00:00<00:01, 378.99it/s]
#  23% 154/674 [00:00<00:01, 367.47it/s]
#  29% 194/674 [00:00<00:01, 378.49it/s]
#  34% 232/674 [00:00<00:01, 369.16it/s]
#  40% 269/674 [00:00<00:01, 368.93it/s]
#  45% 306/674 [00:00<00:00, 368.24it/s]
#  51% 343/674 [00:00<00:00, 368.71it/s]
#  56% 380/674 [00:01<00:00, 364.30it/s]
#  62% 417/674 [00:01<00:00, 362.54it/s]
# ...

# %%
# !python3 "/content/drive/MyDrive/Colab Notebooks/BIOtoken.py" \
  --model_name_or_path "/content/drive/MyDrive/数据/100%_data_train_BiolinkBert_results/checkpoint-504" \
  --validation_file "/content/drive/MyDrive/数据/Val/Data_val.json" \
  --test_file "/content/drive/MyDrive/数据/External/Data_external.json" \
  --do_eval \
  --do_predict \
  --max_seq_length 384 \
  --doc_stride 128 \
  --output_dir "/content/drive/MyDrive/数据/data_external_BioLinkBert_results" \
  --report_to none
# Out:
# Generating validation split: 669 examples [00:00, 905.15 examples/s]
# Generating test split: 529 examples [00:00, 55303.76 examples/s]
# Loading weights: 100% 199/199 [00:16<00:00, 12.20it/s]
# Running tokenizer on validation dataset: 100% 669/669 [00:00<00:00, 696.82 examples/s]
# Running tokenizer on prediction dataset: 100% 529/529 [00:00<00:00, 707.26 examples/s]
# 100% 84/84 [00:13<00:00,  6.75it/s]
#   0% 0/669 [00:00<?, ?it/s]
#   5% 35/669 [00:00<00:01, 344.50it/s]
#  11% 73/669 [00:00<00:01, 363.60it/s]
#  16% 110/669 [00:00<00:01, 363.06it/s]
#  23% 151/669 [00:00<00:01, 377.89it/s]
#  29% 191/669 [00:00<00:01, 382.82it/s]
#  34% 230/669 [00:00<00:01, 373.12it/s]
#  40% 268/669 [00:00<00:01, 371.77it/s]
#  46% 306/669 [00:00<00:00, 368.42it/s]
#  51% 343/669 [00:00<00:00, 352.94it/s]
#  57% 379/669 [00:01<00:00, 348.63it/s]
#  62% 417/669 [00:01<00:00, 355.09it/s]
#  68% 453/669 [00:01<00:00, 355.29it/s]
#  73% 489/669 [00:01<00:00, 354.20it/s]
# ...

# %%
# !mkdir -p "/content/drive/MyDrive/数据/PubmedBert_final_best"
# !cp -r /content/local_results/* "/content/drive/MyDrive/数据/PubmedBert_final_best/"

# %%
# !grep -n "trainer.train" "/content/drive/MyDrive/Colab Notebooks/BIOtoken.py"
# Out:
# 559:        train_result = trainer.train(resume_from_checkpoint=checkpoint)

# %%
# !python3 "/content/drive/MyDrive/Colab Notebooks/qa_BIOtoken - 副本.py" \
--model_name_or_path "/content/drive/MyDrive/张铮资料/BiolinkBert_Best/checkpoint-330" \
--validation_file "/content/测试.json" \
--do_eval \
--per_device_eval_batch_size 16 \
--max_seq_length 384 \
--doc_stride 128 \
--output_dir "/content/drive/MyDrive/张铮资料/BioLinkBERT_External_Results"
# Out:
# Loading weights: 100% 199/199 [00:04<00:00, 44.40it/s, Materializing param=qa_outputs.weight]
# Running tokenizer on validation dataset: 100% 153/153 [00:00<00:00, 608.62 examples/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# 100% 10/10 [03:33<00:00, 22.01s/it]
#   0% 0/153 [00:00<?, ?it/s]
#  18% 27/153 [00:00<00:00, 268.89it/s]
#  41% 62/153 [00:00<00:00, 315.50it/s]
#  61% 94/153 [00:00<00:00, 313.24it/s]
# 100% 153/153 [00:00<00:00, 296.24it/s]
# 100% 10/10 [03:33<00:00, 21.40s/it]
# ***** eval metrics *****
#   eval_bio_FN               =     59
#   eval_bio_FP               =     93
#   eval_bio_TP               =    200
#   eval_bio_strict_f1        = 0.7246
#   eval_bio_strict_precision = 0.6826
#   eval_bio_strict_recall    = 0.7722
#   eval_samples              =    158

# %%
# !pip install transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 58.3 MB/s eta 0:00:00
# ...

# %%
# !pip install transformers==4.30.2
# Out:
# ...
#   Using cached transformers-4.30.2-py3-none-any.whl.metadata (113 kB)
# ...
#   Using cached huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached tokenizers-0.13.3.tar.gz (314 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# Using cached transformers-4.30.2-py3-none-any.whl (7.2 MB)
# Using cached huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tokenizers)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
